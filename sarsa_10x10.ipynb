# %%
import numpy as np
import random
from collections import defaultdict
import matplotlib.pyplot as plt
from frozenlake_env import FrozenLakeEnv

# %%
# set random seed for reproducibility
np.random.seed(25)
random.seed(25)

# %%
# define hyperparameters
GAMMA = 0.99  # Discount factor for future rewards
ALPHA = 0.1  # Learning rate (step size for Q-value updates)
EPSILON = 0.05  # Exploration rate (probability of taking a random action)
EPISODES = 10000  # Number of episodes for training
EPSILON_DECAY = 0.995  # Decay rate for epsilon (reducing exploration over time)
EPSILON_MIN = 0.01  # Minimum epsilon value to maintain some exploration
GRID_SIZE = 10  # grid size (4x4 or 10x10)
HOLE_FRACTION = 0.25  # fraction of holes in the grid
USE_DEFAULT_MAP = True  # Whether to use a predefined map

# create environment
env = FrozenLakeEnv(grid_size=GRID_SIZE, hole_fraction=HOLE_FRACTION, use_default_map=USE_DEFAULT_MAP)

class SARSA: 
    def __init__(self, env, gamma=GAMMA, alpha= ALPHA, epsilon=EPSILON, epsilon_decay=EPSILON_DECAY, epsilon_min=EPSILON_MIN):
        self.env = env
        self.gamma = gamma # Discount factor for future rewards
        self.alpha = alpha # Learning rate (step size for Q-value updates)
        self.epsilon = epsilon # Initial exploration rate
        self.epsilon_decay = epsilon_decay # Decay rate for epsilon over time
        self.epsilon_min = epsilon_min # Minimum value for epsilon to ensure some exploration
        self.Q = defaultdict(lambda: np.zeros(len(env.actions))) # Q-table initialization
        self.returns = defaultdict(list) # Dictionary to store returns for each state-action pair
        self.episode_rewards = [] # Stores total reward per episode
        self.record_goal = [] # Records success (1 if goal reached, 0 otherwise)
        self.record_fail = [] # Records failure (1 if goal not reached, 0 otherwise)
        self.record_path_length = [] # Stores the number of steps in each episode


    # epsilon greedy action selection:
    def choose_action(self, state):
        """
        Selects an action using the epsilon-greedy policy.

        - With probability ε (exploration), chooses a random action.
        - With probability 1 - ε (exploitation), chooses the action with the highest Q-value.

        Parameters:
        - state: The current state of the agent

        Returns:
        - Selected action
        """
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(list(self.env.actions.keys()))  # Explore
        else:
            action_index = np.argmax(self.Q[state])
            return list(self.env.actions.keys())[action_index] 

    def train(self, episodes):
        """
        Trains the agent using the SARSA algorithm.

        **SARSA Algorithm:**
        - Initialize Q-table with zeros.
        - For each episode:
          - Start at the initial state.
          - Choose an action using the ε-greedy policy.
          - Repeat until the episode ends:
            - Take action, observe reward and next state.
            - Choose next action using the ε-greedy policy.
            - Update Q-value using SARSA update rule:
              \[
              Q(s, a) = Q(s, a) + \alpha \left[ R + \gamma Q(s', a') - Q(s, a) \right]
              \]
          - Decay ε to balance exploration vs. exploitation.

        Parameters:
        - episodes: Number of episodes to train

        Returns:
        - Q-table with optimized state-action values
        - List of total rewards per episode
        """
        for episode in range(episodes):
            state = self.env.reset() # Reset environment to start state
            action = self.choose_action(state) # Choose initial action
            episode_rewards = 0 # Tracks total reward for this episode
            done = False # Flag to check if episode is over
            path_length = 0 # Tracks the number of steps taken

            # generate episode
            while not done:
                next_state, reward, done = self.env.step(action) # Execute action and observe next state and reward
                next_action = self.choose_action(next_state) # Choose next action
                episode_rewards += reward # Accumulate reward
                path_length += 1 # Increment step count

                # SARSA Update Rule:
                # 1. Compute the TD target: reward + gamma * Q(next_state, next_action)
                #    This estimates the expected return after taking the next action.
                td_target = reward + self.gamma * self.Q[next_state][next_action] # Compute target value
                # 2. Compute the TD error: TD target - Q(state, action)
                #    This measures the difference between the estimated and current Q-value.
                td_error = td_target - self.Q[state][action] # Temporal difference error
                # 3. Update the Q-value for the current state-action pair:
                #    Q(state, action) += alpha * TD error
                #    This adjusts the Q-value based on the observed reward and next state. 
                self.Q[state][action] += self.alpha * td_error # Update Q-value

                state = next_state # Move to next state
                action = next_action # Move to next action

            # Store episode statistics
            self.episode_rewards.append(episode_rewards)
            self.record_path_length.append(path_length)

            # Track success or failure
            if reward == 1:
                self.record_goal.append(1)
                self.record_fail.append(0)
            else:
                self.record_goal.append(0)
                self.record_fail.append(1)
            
            # Decay epsilon to reduce exploration over time
            # self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

        return self.Q, self.episode_rewards
    
    # Save the Q-table to a plain text file.
    def save_q_table_text(self, filename):
        with open(filename, 'w') as f:
            for state, actions in self.Q.items():
                action_values = ' '.join(map(str, actions))
                f.write(f"{state} {action_values}\n")
                
    # Load the Q-table from a plain text file.
    def load_q_table_text(self, filename):
        self.Q = defaultdict(lambda: np.zeros(len(self.env.actions)))
        with open(filename, 'r') as f:
            for line in f:
                parts = line.strip().split()
                state = int(parts[0])
                actions = np.array([float(x) for x in parts[1:]])
                self.Q[state] = actions   

    # Displays the learned policy as a grid.
    def visualize_policy(self, Q, env):
        policy = np.zeros((self.env.grid_size, self.env.grid_size), dtype=str)
        for state in Q:
            row, col = state // self.env.grid_size, state % self.env.grid_size
            action = np.argmax(Q[state])
            policy[row, col] = self.env.actions[action][0]  # Use first letter of action (U, D, R, L)
        print("Learned Policy:")
        print(policy)

    # Tests the learned policy over a given number of episodes.
    def test_policy(self, Q, env, episodes=10):
        total_rewards = 0
        for episode in range(episodes):
            state = env.reset()
            done = False
            episode_reward = 0
            while not done:
                action = np.argmax(Q[state])  # Greedy policy
                next_state, reward, done = env.step(action)
                episode_reward += reward
                state = next_state
            total_rewards += episode_reward
            print(f"Episode {episode + 1}: Reward = {episode_reward}")
        print(f"Average Reward over {episodes} episodes: {total_rewards / episodes}")

    # Displays the value function as a grid.
    def visualize_value_function(self, Q, env):
        value_function = np.zeros((env.grid_size, env.grid_size))
        for state in Q:
            row, col = state // env.grid_size, state % env.grid_size
            value_function[row, col] = np.max(Q[state])
        print("Value Function:")
        print(value_function)

    # Simulates the agent following the learned policy in the environment.
    def render_policy(self, Q, env):
        state = env.reset()
        done = False
        while not done:
            env.render()
            action = np.argmax(Q[state])  # Greedy policy
            next_state, reward, done = env.step(action)
            state = next_state
        self.env.final()  # Show the final path

# %%
def plot_results(record_goal, record_fail, record_path_length, reward_list, performance_bar):
    """Function to plot the performance of the robot in the figures"""
    fig = plt.figure()
    plt.subplots_adjust(wspace=0.5, hspace=0.7)
    f1 = fig.add_subplot(2, 2, 1)
    f2 = fig.add_subplot(2, 2, 2)
    f3 = fig.add_subplot(2, 2, 3)
    f4 = fig.add_subplot(2, 2, 4)

    # Plot the No. of Successful episodes
    f1.plot(range(len(record_goal)), record_goal, color='red')
    f1.set_title("Successful Episodes")
    f1.set_xlabel("Number of trained episodes")
    f1.set_ylabel("Sucessful Episodes")

    # Plot the No. of Failing episodes
    f2.plot(range(len(record_fail)), record_fail, color='orange')
    f2.set_title("Failing Episodes")
    f2.set_xlabel("Number of trained episodes")
    f2.set_ylabel("Failed Episodes")

    # Plot the path length
    f3.plot(range(len(record_path_length)), record_path_length, color='blue')
    f3.set_title("Successful Path Length")
    f3.set_xlabel("Number of trained episodes")
    f3.set_ylabel("Path Length")

    # Plot the episode reward
    f4.plot(range(len(reward_list)), reward_list, color='yellow')
    f4.set_title("Episode reward")
    f4.set_xlabel("Number of trained episodes")
    f4.set_ylabel("Episode reward")

    plt.figure()
    performance_list = ['Success', 'Fail']
    color_list = ['blue', 'red']
    plt.bar(np.arange(len(performance_bar)), performance_bar, tick_label=performance_list, color=color_list)
    plt.title('Bar/Success and Fail')
    plt.ylabel('Numbers')

    # Show the figures
    plt.show()

# %%
print("Training with SARSA...")
sarsa_agent = SARSA(env)
Q_sarsa, sarsa_rewards = sarsa_agent.train(EPISODES)
print("Training complete!")

# save the Q-table
sarsa_agent.save_q_table_text('q_table_sarsa_10x10.txt')
print("Q-table saved to 'q_table_sarsa_10x10.txt'")

# load the Q-table (optional, if want to test without retraining)
sarsa_agent.load_q_table_text('q_table_sarsa_10x10.txt')
print("Q-table loaded from 'q_table_sarsa_10x10.txt'")

# # visualize the policy 
sarsa_agent.visualize_policy(Q_sarsa, env)  
# # test the policy
sarsa_agent.test_policy(Q_sarsa, env)
# # visualize the value function
sarsa_agent.visualize_value_function(Q_sarsa, env)
# # render the policy
sarsa_agent.render_policy(Q_sarsa, env)

# plot cumulative rewards
plt.figure(figsize=(12, 6))
plt.plot(np.cumsum(sarsa_rewards), label=f"SARSA (Map Size: {GRID_SIZE}x{GRID_SIZE})")
plt.title("Cumulative Rewards Over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Cumulative Reward")
plt.legend()
plt.grid()
plt.show()

# Plot moving average of rewards
window_size = 50  # Moving average window
plt.figure(figsize=(12, 6))
plt.plot(np.convolve(sarsa_rewards, np.ones(window_size)/window_size, mode='valid'),
         label=f"SARSA (Map Size: {GRID_SIZE}x{GRID_SIZE})")
plt.title(f"Moving Average of Rewards (Window Size = {window_size})")
plt.xlabel("Episodes")
plt.ylabel("Average Reward")
plt.legend()
plt.grid()
plt.show()

# Collect data for plotting
record_goal = sarsa_agent.record_goal
record_fail = sarsa_agent.record_fail
record_path_length = sarsa_agent.record_path_length
reward_list = sarsa_rewards
performance_bar = [sum(record_goal), sum(record_fail)]

# Call the plot_results function
plot_results(record_goal, record_fail, record_path_length, sarsa_rewards, performance_bar)
# Out:
# Training with SARSA...
# Training complete!
# Q-table saved to 'q_table_sarsa_10x10.txt'
# Q-table loaded from 'q_table_sarsa_10x10.txt'
# Learned Policy:
# [['D' 'L' 'L' 'L' 'R' 'R' 'D' 'R' 'R' 'D']
#  ['D' 'U' 'U' 'D' 'U' 'U' 'D' 'U' 'D' 'L']
#  ['D' 'L' 'L' 'D' 'L' 'U' 'R' 'R' 'D' 'U']
#  ['D' 'L' 'U' 'D' 'L' 'D' 'D' 'U' 'D' 'D']
#  ['D' 'U' 'D' 'D' 'U' 'U' 'U' 'R' 'D' 'L']
#  ['D' 'L' 'L' 'L' 'R' 'D' 'U' 'D' 'D' 'U']
#  ['D' 'D' 'U' 'D' 'U' 'R' 'R' 'R' 'R' 'D']
#  ['D' 'D' 'D' 'D' 'U' 'D' 'D' 'U' 'U' 'D']
#  ['R' 'R' 'R' 'D' 'R' 'D' 'D' 'L' 'U' 'D']
#  ['U' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'U']]
# Episode 1: Reward = 1
# Episode 2: Reward = 1
# Episode 3: Reward = 1
# Episode 4: Reward = 1
# Episode 5: Reward = 1
# Episode 6: Reward = 1
# Episode 7: Reward = 1
# Episode 8: Reward = 1
# Episode 9: Reward = 1
# Episode 10: Reward = 1
# Average Reward over 10 episodes: 1.0
# Value Function:
# [[ 6.46642041e-01  4.98553868e-01  2.82170565e-01  2.43453058e-01
#   -5.19258200e-03 -6.01207770e-03 -3.91211576e-03  1.38801109e-03
#    3.99622424e-03  9.83970690e-03]
#  [ 6.52768137e-01  0.00000000e+00  2.47286571e-01  7.21000807e-02
#    0.00000000e+00 -3.72460161e-03 -3.89228897e-03  0.00000000e+00
#    4.71153373e-02  2.22426680e-02]
#  [ 5.53848148e-01  5.73547962e-01  4.30767589e-01  1.58986876e-01
#   -7.49021871e-03  0.00000000e+00 -3.81818968e-03  2.78168508e-02
#    1.21025157e-01  0.00000000e+00]
#  [ 5.86214794e-01  5.69470932e-01  0.00000000e+00  2.80672294e-01
#   -4.41987069e-03 -2.16378338e-03 -4.26353909e-09  0.00000000e+00
#    2.20243597e-01  1.86018045e-04]
#  [ 7.35594403e-01  0.00000000e+00 -2.10086081e-02  4.15107412e-01
#    0.00000000e+00 -6.75070799e-03 -1.81939201e-08  6.36202440e-03
#    3.60632093e-01  3.41643029e-03]
#  [ 7.56933441e-01  6.24479056e-01  6.18758105e-01  5.60473517e-01
#   -5.81686191e-05 -2.42391536e-04  0.00000000e+00  6.56840276e-03
#    5.07292622e-01  0.00000000e+00]
#  [ 7.79098691e-01  6.41716075e-01  0.00000000e+00  5.67037668e-01
#   -1.66330658e-05  3.44281684e-03  4.12156715e-02  2.31139489e-01
#    6.71351656e-01  8.62949349e-01]
#  [ 8.03683380e-01  7.55677254e-01  7.30375578e-01  7.40489050e-01
#    0.00000000e+00  7.48957062e-01  7.19831080e-01  0.00000000e+00
#    1.10392184e-02  8.65815894e-01]
#  [ 8.41204847e-01  8.71229402e-01  9.01119380e-01  9.22976116e-01
#    9.05819177e-01  9.36179422e-01  8.34469363e-01  7.37438645e-01
#    0.00000000e+00  9.97261073e-01]
#  [ 7.25998118e-01  5.86793139e-01  7.71228395e-01  9.32179208e-01
#    9.39397685e-01  9.52665697e-01  9.70508944e-01  9.89999992e-01
#    1.00000000e+00  0.00000000e+00]]
# shortest path: 17
# longest path: 1471
# the shortest route is shown in red

# %%
# Plot Steps per Episode
plt.figure(figsize=(12, 6))
plt.plot(record_path_length, label="Steps per Episode", color="blue")
plt.title("Steps Taken per Episode")
plt.xlabel("Episodes")
plt.ylabel("Steps")
plt.legend()
plt.grid()
plt.show()

# Plot Success Rate (Rolling Average)
window_size = 10  # Rolling window to smooth success rate
rolling_success = np.convolve(record_goal, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(12, 6))
plt.plot(rolling_success, label="Success Rate (Rolling Avg)", color="green")
plt.title("Moving Average of Success Rate (Window Size = 10)")
plt.xlabel("Episodes")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
plt.show()

final_success_rate = sum(sarsa_agent.record_goal) / len(sarsa_agent.record_goal) * 100
print(f"Final Success Rate: {final_success_rate:.2f}%")
# Out:
# Final Success Rate: 91.19%
